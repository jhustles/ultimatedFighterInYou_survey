# %% [markdown]
# ## A

# %%
# Run this first
# Import BeautifulSoup
from bs4 import BeautifulSoup
from splinter import Browser 
import requests
import numpy 
import pandas as pd

soup = BeautifulSoup

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2
url = 'http://ufcstats.com/statistics/fighters?char=a&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


A_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(A_list["link1"])
A_Soup = ""
for link in list(A_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    A_Soup +=   "\n" + link + "\n"
    A_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/93fe7332d16c6ad9
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/15df64c02b6b0fde
# Level 2
# CAREER STATISTICS:
# SLpM: 3.29
# Str. Acc.: 38%
# SApM: 4.41
# Str. Def: 57%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 77%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/b361180739bed4b0
# Level 2
# CAREER STATISTICS:
# SLpM: 1.35
# Str. Acc.: 30%
# SApM: 3.55
# Str. Def: 38%
# TD Avg.: 1.07
# TD Acc.: 33%
# TD Def.: 66%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/2f5cbecbbe18bac4
# Level 2
# CAREER STATISTICS:
# SLpM: 2.64
# Str. Acc.: 44%
# SApM: 2.36
# Str. Def: 60%
# TD Avg.: 1.34
# TD Acc.: 24%
# TD Def.: 66%
# Sub. Avg.: 0.2
# Complete
# Level 1
# http://ufcstats.com/fighter-details/c0ed7b208197e8de
# Level 2
# ...

# %%
#6
A_Soup
file1 = open("A_Soup_raw_data.txt","w")
file1.write(A_Soup)
file1.close()

# %%
#7

f = open("./A_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

A_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])
A_df.head()
#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-f89f210cd2f0> in <module>()
#       1 #7
#       2
# ----> 3 f = open("./A_Soup_raw_data.txt", "r")
#       4 #print("Raw Data:")
#       5 #print(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: './A_Soup_raw_data.txt'

# %%
#8
A_df['SLpM'] = A_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
A_df['SApM'] = A_df["SApM"].map(lambda x: x.replace("SApM:", ""))
A_df['Str. Def'] = A_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
A_df['TD Avg'] = A_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
A_df['TD Acc'] = A_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
A_df['TD Def'] = A_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
A_df['Sub. Avg'] = A_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
A_df.head()
# Final CSV 
#A_df.to_csv("A_soup_final_drew.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-0247781795e8> in <module>()
# ----> 1 A_df['SLpM'] = A_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
#       2 A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
#       3 A_df['SApM'] = A_df["SApM"].map(lambda x: x.replace("SApM:", ""))
#       4 A_df['Str. Def'] = A_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
#       5 A_df['TD Avg'] = A_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
#
# NameError: name 'A_df' is not defined

# %%
#9
data = pd.read_csv("A_Soup.csv")
data = data.drop(columns=["Unnamed: 0"])

data.to_csv("A_soup_final_drew.csv", index=False)

# %% [markdown]
# ## B

# %%
#1

executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=b&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3

soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


B_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(B_list["link1"])
B_Soup = ""
for link in list(B_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    B_Soup +=   "\n" + link + "\n"
    B_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/39cc64bf0a269db9
# Level 2
# CAREER STATISTICS:
# SLpM: 1.12
# Str. Acc.: 41%
# SApM: 3.65
# Str. Def: 40%
# TD Avg.: 2.92
# TD Acc.: 80%
# TD Def.: 72%
# Sub. Avg.: 2.2
# Complete
# Level 1
# http://ufcstats.com/fighter-details/fd5b6598a3b70c0a
# Level 2
# CAREER STATISTICS:
# SLpM: 3.08
# Str. Acc.: 31%
# SApM: 3.14
# Str. Def: 51%
# TD Avg.: 0.89
# TD Acc.: 16%
# TD Def.: 48%
# Sub. Avg.: 0.8
# Complete
# Level 1
# http://ufcstats.com/fighter-details/c0ab242c40decc55
# Level 2
# CAREER STATISTICS:
# SLpM: 2.82
# Str. Acc.: 43%
# SApM: 1.39
# Str. Def: 71%
# TD Avg.: 3.37
# TD Acc.: 44%
# TD Def.: 80%
# Sub. Avg.: 0.4
# Complete
# Level 1
# http://ufcstats.com/fighter-details/4fcf6e0c4e0e6664
# Level 2
# CAREER STATISTICS:
# SLpM: 3.74
# Str. Acc.: 71%
# SApM: 4.90
# Str. Def: 32%
# TD Avg.: 1.75
# TD Acc.: 12%
# TD Def.: 100%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/82d4c957649faf9b
# Level 2
# ...

# %%
#6
B_Soup
file1 = open("B_Soup_raw_data.txt","w")
file1.write(B_Soup)
file1.close()

# %%
#7

f = open("./B_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

B_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])
B_df.head()
#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")
# Out:
#                                                link1         SLpM  \
# 0  http://ufcstats.com/fighter-details/39cc64bf0a...   SLpM: 1.12
# 1   http://ufcstats.com/fighter-details/fd5b6598a...   SLpM: 3.08
# 2   http://ufcstats.com/fighter-details/c0ab242c4...   SLpM: 2.82
# 3   http://ufcstats.com/fighter-details/4fcf6e0c4...   SLpM: 3.74
# 4   http://ufcstats.com/fighter-details/82d4c9576...   SLpM: 4.07
#
#           Str. Acc         SApM        Str. Def          TD Avg  \
# 0   Str. Acc.: 41%   SApM: 3.65   Str. Def: 40%   TD Avg.: 2.92
# 1   Str. Acc.: 31%   SApM: 3.14   Str. Def: 51%   TD Avg.: 0.89
# 2   Str. Acc.: 43%   SApM: 1.39   Str. Def: 71%   TD Avg.: 3.37
# 3   Str. Acc.: 71%   SApM: 4.90   Str. Def: 32%   TD Avg.: 1.75
# 4   Str. Acc.: 59%   SApM: 5.93   Str. Def: 33%   TD Avg.: 0.00
#
#           TD Acc          TD Def         Sub. Avg
# 0   TD Acc.: 80%    TD Def.: 72%   Sub. Avg.: 2.2
# 1   TD Acc.: 16%    TD Def.: 48%   Sub. Avg.: 0.8
# ...

# %%
# Out:
# <_io.TextIOWrapper name='./B_Soup_raw_data.txt' mode='r' encoding='UTF-8'>

# %%
#8

B_df['SLpM'] = B_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
B_df['Str. Acc'] = B_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
B_df['SApM'] = B_df["SApM"].map(lambda x: x.replace("SApM:", ""))
B_df['Str. Def'] = B_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
B_df['TD Avg'] = B_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
B_df['TD Acc'] = B_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
B_df['TD Def'] = B_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
B_df['Sub. Avg'] = B_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
B_df.head()
# Final CSV 
B_df.to_csv("B_soup_final_.csv", index=False)

# %%
#9

# data = pd.read_csv("B_Soup.csv")
# data = data.drop(columns=["Unnamed: 0"])

# data.to_csv("B_soup_final_.csv", index=False)

# %% [markdown]
# ## C

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2
url = 'http://ufcstats.com/statistics/fighters?char=c&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


C_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(C_list["link1"])
C_Soup = ""
for link in list(C_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    C_Soup +=   "\n" + link + "\n"
    C_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/7cdd3e5d3aa9cb39
# Level 2
# CAREER STATISTICS:
# SLpM: 2.02
# Str. Acc.: 47%
# SApM: 1.98
# Str. Def: 62%
# TD Avg.: 2.89
# TD Acc.: 35%
# TD Def.: 37%
# Sub. Avg.: 1.2
# Complete
# Level 1
# http://ufcstats.com/fighter-details/ce7871949b0ed2bf
# Level 2
# CAREER STATISTICS:
# SLpM: 1.21
# Str. Acc.: 66%
# SApM: 0.61
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/7aa3d6964eff4877
# Level 2
# CAREER STATISTICS:
# SLpM: 3.98
# Str. Acc.: 48%
# SApM: 2.86
# Str. Def: 64%
# TD Avg.: 0.53
# TD Acc.: 75%
# TD Def.: 58%
# Sub. Avg.: 0.8
# Complete
# Level 1
# http://ufcstats.com/fighter-details/b1e5bcaad32a3cac
# Level 2
# CAREER STATISTICS:
# SLpM: 3.70
# Str. Acc.: 36%
# SApM: 7.94
# Str. Def: 42%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 69%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/90d28fee0af74f2d
# Level 2
# ...

# %%
#6
C_Soup
file1 = open("C_Soup_raw_data.txt","w")
file1.write(C_Soup)
file1.close()

# %%
#7

f = open("./C_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

C_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
C_df.head()
# Out:
#                                                link1         SLpM  \
# 0  http://ufcstats.com/fighter-details/7cdd3e5d3a...   SLpM: 2.02
# 1   http://ufcstats.com/fighter-details/ce7871949...   SLpM: 1.21
# 2   http://ufcstats.com/fighter-details/7aa3d6964...   SLpM: 3.98
# 3   http://ufcstats.com/fighter-details/b1e5bcaad...   SLpM: 3.70
# 4   http://ufcstats.com/fighter-details/90d28fee0...   SLpM: 0.00
#
#           Str. Acc         SApM        Str. Def          TD Avg  \
# 0   Str. Acc.: 47%   SApM: 1.98   Str. Def: 62%   TD Avg.: 2.89
# 1   Str. Acc.: 66%   SApM: 0.61    Str. Def: 0%   TD Avg.: 0.00
# 2   Str. Acc.: 48%   SApM: 2.86   Str. Def: 64%   TD Avg.: 0.53
# 3   Str. Acc.: 36%   SApM: 7.94   Str. Def: 42%   TD Avg.: 0.00
# 4    Str. Acc.: 0%   SApM: 0.00    Str. Def: 0%   TD Avg.: 0.00
#
#           TD Acc         TD Def         Sub. Avg
# 0   TD Acc.: 35%   TD Def.: 37%   Sub. Avg.: 1.2
# 1    TD Acc.: 0%    TD Def.: 0%   Sub. Avg.: 0.0
# ...

# %%
#8
C_df['SLpM'] = C_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
C_df['Str. Acc'] = C_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
C_df['SApM'] = C_df["SApM"].map(lambda x: x.replace("SApM:", ""))
C_df['Str. Def'] = C_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
C_df['TD Avg'] = C_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
C_df['TD Acc'] = C_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
C_df['TD Def'] = C_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
C_df['Sub. Avg'] = C_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
C_df.head()
# Final CSV 
C_df.to_csv("C_soup_final_.csv", index=False)

# %%
#9
# data = pd.read_csv("C_Soup.csv")
# data = data.drop(columns=["Unnamed: 0"])

# data.to_csv("C_soup_final_drew.csv", index=False)

# %% [markdown]
# ## D

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=d&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


D_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(D_list["link1"])
D_Soup = ""
for link in list(D_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    D_Soup +=   "\n" + link + "\n"
    D_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/ac45450f75d14f16
# Level 2
# CAREER STATISTICS:
# SLpM: 2.40
# Str. Acc.: 33%
# SApM: 0.00
# Str. Def: 100%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 100%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/3b6d84343579fd33
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/b102c26727306ab6
# Level 2
# CAREER STATISTICS:
# SLpM: 1.38
# Str. Acc.: 38%
# SApM: 2.23
# Str. Def: 65%
# TD Avg.: 1.95
# TD Acc.: 39%
# TD Def.: 86%
# Sub. Avg.: 0.6
# Complete
# Level 1
# http://ufcstats.com/fighter-details/6f7c616b98e18c29
# Level 2
# CAREER STATISTICS:
# SLpM: 2.27
# Str. Acc.: 46%
# SApM: 2.25
# Str. Def: 45%
# TD Avg.: 3.18
# TD Acc.: 31%
# TD Def.: 50%
# Sub. Avg.: 1.9
# Complete
# Level 1
# http://ufcstats.com/fighter-details/b0bd0c5425668b8f
# Level 2
# ...

# %%
#6
D_Soup
file1 = open("D_Soup_raw_data.txt","w")
file1.write(D_Soup)
file1.close()

# %%
#7

f = open("./D_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

D_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
D_df['SLpM'] = D_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
D_df['Str. Acc'] = D_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
D_df['SApM'] = D_df["SApM"].map(lambda x: x.replace("SApM:", ""))
D_df['Str. Def'] = D_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
D_df['TD Avg'] = D_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
D_df['TD Acc'] = D_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
D_df['TD Def'] = D_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
D_df['Sub. Avg'] = D_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
D_df.head()
# Final CSV 
D_df.to_csv("D_soup_final_.csv", index=False)

# %% [markdown]
# ## E

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=e&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


E_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(E_list["link1"])
E_Soup = ""
for link in list(E_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    E_Soup +=   "\n" + link + "\n"
    E_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/ee457ef1e1c326c1
# Level 2
# CAREER STATISTICS:
# SLpM: 0.50
# Str. Acc.: 55%
# SApM: 0.20
# Str. Def: 33%
# TD Avg.: 3.00
# TD Acc.: 100%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/5713c1d2fac539ac
# Level 2
# CAREER STATISTICS:
# SLpM: 4.15
# Str. Acc.: 43%
# SApM: 7.32
# Str. Def: 40%
# TD Avg.: 3.97
# TD Acc.: 100%
# TD Def.: 16%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/05866d8c3a321856
# Level 2
# CAREER STATISTICS:
# SLpM: 2.21
# Str. Acc.: 35%
# SApM: 3.92
# Str. Def: 42%
# TD Avg.: 1.38
# TD Acc.: 33%
# TD Def.: 81%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/bc7230f231701d66
# Level 2
# CAREER STATISTICS:
# SLpM: 3.51
# Str. Acc.: 37%
# SApM: 4.28
# Str. Def: 61%
# TD Avg.: 0.75
# TD Acc.: 22%
# TD Def.: 66%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/4acb99524a9a81ab
# Level 2
# ...

# %%
#6
E_Soup
file1 = open("E_Soup_raw_data.txt","w")
file1.write(E_Soup)
file1.close()

# %%
#7

f = open("./E_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

E_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
E_df['SLpM'] = E_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
E_df['Str. Acc'] = E_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
E_df['SApM'] = E_df["SApM"].map(lambda x: x.replace("SApM:", ""))
E_df['Str. Def'] = E_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
E_df['TD Avg'] = E_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
E_df['TD Acc'] = E_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
E_df['TD Def'] = E_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
E_df['Sub. Avg'] = E_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
E_df.head()
# Final CSV 
E_df.to_csv("E_soup_final_.csv", index=False)

# %% [markdown]
# ## F

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=f&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


F_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(F_list["link1"])
F_Soup = ""
for link in list(F_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    F_Soup +=   "\n" + link + "\n"
    F_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/6224e8d0a34264eb
# Level 2
# CAREER STATISTICS:
# SLpM: 2.28
# Str. Acc.: 32%
# SApM: 6.25
# Str. Def: 44%
# TD Avg.: 1.01
# TD Acc.: 25%
# TD Def.: 33%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/78114b7199cef90c
# Level 2
# CAREER STATISTICS:
# SLpM: 2.68
# Str. Acc.: 41%
# SApM: 2.52
# Str. Def: 64%
# TD Avg.: 1.59
# TD Acc.: 31%
# TD Def.: 60%
# Sub. Avg.: 0.9
# Complete
# Level 1
# http://ufcstats.com/fighter-details/8c020156779f7888
# Level 2
# CAREER STATISTICS:
# SLpM: 4.03
# Str. Acc.: 41%
# SApM: 4.00
# Str. Def: 62%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 100%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/40389d39a92f5bfa
# Level 2
# CAREER STATISTICS:
# SLpM: 1.19
# Str. Acc.: 38%
# SApM: 0.66
# Str. Def: 70%
# TD Avg.: 3.44
# TD Acc.: 64%
# TD Def.: 100%
# Sub. Avg.: 0.4
# Complete
# Level 1
# http://ufcstats.com/fighter-details/e17ac6410c8377f4
# Level 2
# ...

# %%
#6
F_Soup
file1 = open("F_Soup_raw_data.txt","w")
file1.write(F_Soup)
file1.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5277161865e5> in <module>()
#       1 #6
# ----> 2 F_Soup
#       3 file1 = open("F_Soup_raw_data.txt","w")
#       4 file1.write(F_Soup)
#       5 file1.close()
#
# NameError: name 'F_Soup' is not defined

# %%
#7

f = open("./F_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

F_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
F_df['SLpM'] = F_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
F_df['Str. Acc'] = F_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
F_df['SApM'] = F_df["SApM"].map(lambda x: x.replace("SApM:", ""))
F_df['Str. Def'] = F_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
F_df['TD Avg'] = F_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
F_df['TD Acc'] = F_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
F_df['TD Def'] = F_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
F_df['Sub. Avg'] = F_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
F_df.head()
# Final CSV 
F_df.to_csv("F_soup_final_.csv", index=False)

# %% [markdown]
# ## G

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=g&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


G_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(G_list["link1"])
G_Soup = ""
for link in list(G_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    G_Soup +=   "\n" + link + "\n"
    G_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/fcd8b623892b9a10
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/fe98f86284a6eeb3
# Level 2
# CAREER STATISTICS:
# SLpM: 4.06
# Str. Acc.: 65%
# SApM: 4.26
# Str. Def: 46%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 50%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/ec34349e7dffcde7
# Level 2
# CAREER STATISTICS:
# SLpM: 3.17
# Str. Acc.: 42%
# SApM: 4.38
# Str. Def: 58%
# TD Avg.: 3.34
# TD Acc.: 47%
# TD Def.: 58%
# Sub. Avg.: 0.8
# Complete
# Level 1
# http://ufcstats.com/fighter-details/a7a79b8efbceaaac
# Level 2
# CAREER STATISTICS:
# SLpM: 0.99
# Str. Acc.: 27%
# SApM: 0.99
# Str. Def: 57%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 50%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/9e8f6c728eb01124
# Level 2
# ...

# %%
#6
G_Soup
file1 = open("G_Soup_raw_data.txt","w")
file1.write(G_Soup)
file1.close()

# %%
#7

f = open("./G_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

G_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
G_df['SLpM'] = G_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
G_df['Str. Acc'] = G_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
G_df['SApM'] = G_df["SApM"].map(lambda x: x.replace("SApM:", ""))
G_df['Str. Def'] = G_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
G_df['TD Avg'] = G_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
G_df['TD Acc'] = G_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
G_df['TD Def'] = G_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
G_df['Sub. Avg'] = G_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
G_df.head()
# Final CSV 
G_df.to_csv("G_soup_final_.csv", index=False)

# %% [markdown]
# ## H

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=h&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


H_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(H_list["link1"])
H_Soup = ""
for link in list(H_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    H_Soup +=   "\n" + link + "\n"
    H_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/bf12aca029bfcc47
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/99793cf88c5adeee
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/38c626ca912c7bac
# Level 2
# CAREER STATISTICS:
# SLpM: 3.00
# Str. Acc.: 46%
# SApM: 3.00
# Str. Def: 66%
# TD Avg.: 0.68
# TD Acc.: 60%
# TD Def.: 40%
# Sub. Avg.: 0.2
# Complete
# Level 1
# http://ufcstats.com/fighter-details/219a254e15d60135
# Level 2
# CAREER STATISTICS:
# SLpM: 2.79
# Str. Acc.: 47%
# SApM: 4.14
# Str. Def: 46%
# TD Avg.: 1.72
# TD Acc.: 33%
# TD Def.: 85%
# Sub. Avg.: 0.9
# Complete
# Level 1
# http://ufcstats.com/fighter-details/4955c524c2a71469
# Level 2
# ...

# %%
#6
H_Soup
file1 = open("H_Soup_raw_data.txt","w")
file1.write(H_Soup)
file1.close()

# %%
#7

f = open("./H_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

H_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
H_df['SLpM'] = H_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
H_df['Str. Acc'] = H_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
H_df['SApM'] = H_df["SApM"].map(lambda x: x.replace("SApM:", ""))
H_df['Str. Def'] = H_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
H_df['TD Avg'] = H_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
H_df['TD Acc'] = H_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
H_df['TD Def'] = H_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
H_df['Sub. Avg'] = H_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
H_df.head()
# Final CSV 
H_df.to_csv("H_soup_final_.csv", index=False)

# %% [markdown]
# ## I

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=i&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


I_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(I_list["link1"])
I_Soup = ""
for link in list(I_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    I_Soup +=   "\n" + link + "\n"
    I_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/59279a7c978f7da0
# Level 2
# CAREER STATISTICS:
# SLpM: 4.20
# Str. Acc.: 41%
# SApM: 4.26
# Str. Def: 62%
# TD Avg.: 0.69
# TD Acc.: 20%
# TD Def.: 73%
# Sub. Avg.: 0.3
# Complete
# Level 1
# http://ufcstats.com/fighter-details/c3218c810959d279
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/4565d435005319c0
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/82a5152216251682
# Level 2
# CAREER STATISTICS:
# SLpM: 4.15
# Str. Acc.: 49%
# SApM: 3.07
# Str. Def: 61%
# TD Avg.: 2.73
# TD Acc.: 34%
# TD Def.: 54%
# Sub. Avg.: 1.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/7b6ce3a9460565b5
# Level 2
# ...

# %%
#6
I_Soup
file1 = open("I_Soup_raw_data.txt","w")
file1.write(I_Soup)
file1.close()

# %%
#7

f = open("./I_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

I_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-71-dc6338a3759e> in <module>()
#      15     final_data.append(data[index:index+9])
#      16
# ---> 17 I_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])
#      18
#      19 #A_soups_UP = f
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     385                     if is_named_tuple(data[0]) and columns is None:
#     386                         columns = data[0]._fields
# --> 387                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     388                     columns = _ensure_index(columns)
#     389
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _to_arrays(data, columns, coerce_float, dtype)
# ...

# %%
#8
I_df['SLpM'] = I_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
I_df['Str. Acc'] = I_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
I_df['SApM'] = I_df["SApM"].map(lambda x: x.replace("SApM:", ""))
I_df['Str. Def'] = I_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
I_df['TD Avg'] = I_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
I_df['TD Acc'] = I_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
I_df['TD Def'] = I_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
I_df['Sub. Avg'] = I_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
I_df.head()
# Final CSV 
I_df.to_csv("I_soup_final_.csv", index=False)

# %% [markdown]
# ## J

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=j&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


J_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(J_list["link1"])
J_Soup = ""
for link in list(J_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    J_Soup +=   "\n" + link + "\n"
    J_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/b4eeac608fc82f88
# Level 2
# CAREER STATISTICS:
# SLpM: 3.06
# Str. Acc.: 41%
# SApM: 2.93
# Str. Def: 62%
# TD Avg.: 1.94
# TD Acc.: 60%
# TD Def.: 82%
# Sub. Avg.: 0.1
# Complete
# Level 1
# http://ufcstats.com/fighter-details/13b2f59210dda9cc
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/ce783bf73b5131f9
# Level 2
# CAREER STATISTICS:
# SLpM: 2.19
# Str. Acc.: 33%
# SApM: 3.44
# Str. Def: 32%
# TD Avg.: 1.91
# TD Acc.: 71%
# TD Def.: 16%
# Sub. Avg.: 2.3
# Complete
# Level 1
# http://ufcstats.com/fighter-details/ffc088e64fab57e9
# Level 2
# CAREER STATISTICS:
# SLpM: 3.25
# Str. Acc.: 54%
# SApM: 2.51
# Str. Def: 55%
# TD Avg.: 1.52
# TD Acc.: 56%
# TD Def.: 73%
# Sub. Avg.: 0.1
# Complete
# Level 1
# http://ufcstats.com/fighter-details/ad32471f01e7b1a5
# Level 2
# ...

# %%
#6
J_Soup
file1 = open("J_Soup_raw_data.txt","w")
file1.write(J_Soup)
file1.close()

# %%
#7

f = open("./J_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

J_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
J_df['SLpM'] = J_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
J_df['Str. Acc'] = J_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
J_df['SApM'] = J_df["SApM"].map(lambda x: x.replace("SApM:", ""))
J_df['Str. Def'] = J_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
J_df['TD Avg'] = J_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
J_df['TD Acc'] = J_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
J_df['TD Def'] = J_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
J_df['Sub. Avg'] = J_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
J_df.head()
# Final CSV 
J_df.to_csv("J_soup_final_.csv", index=False)

# %% [markdown]
# ## K

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=k&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


K_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(K_list["link1"])
K_Soup = ""
for link in list(K_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    K_Soup +=   "\n" + link + "\n"
    K_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/b180f05acb24d430
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/c1ea9d56cd953586
# Level 2
# CAREER STATISTICS:
# SLpM: 2.60
# Str. Acc.: 36%
# SApM: 5.29
# Str. Def: 38%
# TD Avg.: 1.86
# TD Acc.: 14%
# TD Def.: 50%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/2525a853486ee670
# Level 2
# CAREER STATISTICS:
# SLpM: 3.57
# Str. Acc.: 41%
# SApM: 4.63
# Str. Def: 62%
# TD Avg.: 4.00
# TD Acc.: 42%
# TD Def.: 83%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/304fcd812f12c589
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/9336e86cfd4ceaa1
# Level 2
# ...

# %%
#6
K_Soup
file1 = open("K_Soup_raw_data.txt","w")
file1.write(K_Soup)
file1.close()

# %%
#7

f = open("./K_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

K_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
K_df['SLpM'] = K_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
K_df['Str. Acc'] = K_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
K_df['SApM'] = K_df["SApM"].map(lambda x: x.replace("SApM:", ""))
K_df['Str. Def'] = K_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
K_df['TD Avg'] = K_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
K_df['TD Acc'] = K_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
K_df['TD Def'] = K_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
K_df['Sub. Avg'] = K_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
K_df.head()
# Final CSV 
K_df.to_csv("K_soup_final_.csv", index=False)

# %% [markdown]
# ## L

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=l&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


L_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(L_list["link1"])
L_Soup = ""
for link in list(L_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    L_Soup +=   "\n" + link + "\n"
    L_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/b3fb8d2293e17a59
# Level 2
# CAREER STATISTICS:
# SLpM: 0.75
# Str. Acc.: 39%
# SApM: 1.10
# Str. Def: 46%
# TD Avg.: 3.00
# TD Acc.: 100%
# TD Def.: 0%
# Sub. Avg.: 0.8
# Complete
# Level 1
# http://ufcstats.com/fighter-details/5108b169b5fe1f86
# Level 2
# CAREER STATISTICS:
# SLpM: 2.53
# Str. Acc.: 36%
# SApM: 5.33
# Str. Def: 44%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 71%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/4fe1d105af549845
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/eb84192d1a97f69e
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/d4691518d012b9e7
# Level 2
# ...

# %%
#6
L_Soup
file1 = open("L_Soup_raw_data.txt","w")
file1.write(L_Soup)
file1.close()

# %%
#7

f = open("./L_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

L_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
L_df['SLpM'] = L_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
L_df['Str. Acc'] = L_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
L_df['SApM'] = L_df["SApM"].map(lambda x: x.replace("SApM:", ""))
L_df['Str. Def'] = L_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
L_df['TD Avg'] = L_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
L_df['TD Acc'] = L_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
L_df['TD Def'] = L_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
L_df['Sub. Avg'] = L_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
L_df.head()
# Final CSV 
L_df.to_csv("L_soup_final_.csv", index=False)

# %% [markdown]
# ## M

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=m&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


M_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(M_list["link1"])
M_Soup = ""
for link in list(M_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    M_Soup +=   "\n" + link + "\n"
    M_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/98a6b2361045898f
# Level 2
# CAREER STATISTICS:
# SLpM: 3.54
# Str. Acc.: 45%
# SApM: 4.56
# Str. Def: 53%
# TD Avg.: 1.56
# TD Acc.: 60%
# TD Def.: 33%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/ed74afc8b5b47a61
# Level 2
# CAREER STATISTICS:
# SLpM: 4.92
# Str. Acc.: 54%
# SApM: 3.96
# Str. Def: 65%
# TD Avg.: 1.85
# TD Acc.: 45%
# TD Def.: 78%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/2be6596a9db33bf5
# Level 2
# CAREER STATISTICS:
# SLpM: 1.55
# Str. Acc.: 52%
# SApM: 2.70
# Str. Def: 46%
# TD Avg.: 1.43
# TD Acc.: 16%
# TD Def.: 35%
# Sub. Avg.: 2.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/f3388d2cf7ab3f64
# Level 2
# CAREER STATISTICS:
# SLpM: 1.80
# Str. Acc.: 50%
# SApM: 2.04
# Str. Def: 46%
# TD Avg.: 7.19
# TD Acc.: 80%
# TD Def.: 80%
# Sub. Avg.: 5.4
# Complete
# Level 1
# http://ufcstats.com/fighter-details/cbd5d3cdd862e90e
# Level 2
# ...

# %%
#6
M_Soup
file1 = open("M_Soup_raw_data.txt","w")
file1.write(L_Soup)
file1.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fd811577ce19> in <module>()
#       1 #6
# ----> 2 M_Soup
#       3 file1 = open("M_Soup_raw_data.txt","w")
#       4 file1.write(L_Soup)
#       5 file1.close()
#
# NameError: name 'M_Soup' is not defined

# %%
#7

f = open("./M_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

M_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
M_df['SLpM'] = M_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
M_df['Str. Acc'] = M_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
M_df['SApM'] = M_df["SApM"].map(lambda x: x.replace("SApM:", ""))
M_df['Str. Def'] = M_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
M_df['TD Avg'] = M_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
M_df['TD Acc'] = M_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
M_df['TD Def'] = M_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
M_df['Sub. Avg'] = M_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
M_df.head()
# Final CSV 
M_df.to_csv("M_soup_final_.csv", index=False)

# %% [markdown]
# ## N

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=n&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


N_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(N_list["link1"])
N_Soup = ""
for link in list(M_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    N_Soup +=   "\n" + link + "\n"
    N_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/98a6b2361045898f
# Level 2
# CAREER STATISTICS:
# SLpM: 3.54
# Str. Acc.: 45%
# SApM: 4.56
# Str. Def: 53%
# TD Avg.: 1.56
# TD Acc.: 60%
# TD Def.: 33%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/ed74afc8b5b47a61
# Level 2
# CAREER STATISTICS:
# SLpM: 4.92
# Str. Acc.: 54%
# SApM: 3.96
# Str. Def: 65%
# TD Avg.: 1.85
# TD Acc.: 45%
# TD Def.: 78%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/2be6596a9db33bf5
# Level 2
# CAREER STATISTICS:
# SLpM: 1.55
# Str. Acc.: 52%
# SApM: 2.70
# Str. Def: 46%
# TD Avg.: 1.43
# TD Acc.: 16%
# TD Def.: 35%
# Sub. Avg.: 2.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/f3388d2cf7ab3f64
# Level 2
# CAREER STATISTICS:
# SLpM: 1.80
# Str. Acc.: 50%
# SApM: 2.04
# Str. Def: 46%
# TD Avg.: 7.19
# TD Acc.: 80%
# TD Def.: 80%
# Sub. Avg.: 5.4
# Complete
# Level 1
# http://ufcstats.com/fighter-details/cbd5d3cdd862e90e
# Level 2
# ...

# %%
#6
N_Soup
file1 = open("N_Soup_raw_data.txt","w")
file1.write(L_Soup)
file1.close()

# %%
#7

f = open("./N_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

N_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
N_df['SLpM'] = N_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
N_df['Str. Acc'] = N_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
N_df['SApM'] = N_df["SApM"].map(lambda x: x.replace("SApM:", ""))
N_df['Str. Def'] = N_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
N_df['TD Avg'] = N_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
N_df['TD Acc'] = N_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
N_df['TD Def'] = N_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
N_df['Sub. Avg'] = N_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
N_df.head()
# Final CSV 
N_df.to_csv("N_soup_final_.csv", index=False)

# %% [markdown]
# ## O

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=O&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


O_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(O_list["link1"])
O_Soup = ""
for link in list(O_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    O_Soup +=   "\n" + link + "\n"
    O_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/20bcc9966affb19c
# Level 2
# CAREER STATISTICS:
# SLpM: 1.31
# Str. Acc.: 31%
# SApM: 1.92
# Str. Def: 69%
# TD Avg.: 6.39
# TD Acc.: 54%
# TD Def.: 25%
# Sub. Avg.: 0.2
# Complete
# Level 1
# http://ufcstats.com/fighter-details/d25b93992f285953
# Level 2
# CAREER STATISTICS:
# SLpM: 3.77
# Str. Acc.: 46%
# SApM: 4.78
# Str. Def: 57%
# TD Avg.: 0.94
# TD Acc.: 100%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/cb52f9490c2dc069
# Level 2
# CAREER STATISTICS:
# SLpM: 5.46
# Str. Acc.: 48%
# SApM: 6.77
# Str. Def: 45%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 30%
# Sub. Avg.: 0.5
# Complete
# Level 1
# http://ufcstats.com/fighter-details/69ea0119f6f0dfe0
# Level 2
# CAREER STATISTICS:
# SLpM: 4.00
# Str. Acc.: 56%
# SApM: 5.10
# Str. Def: 54%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 100%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/46effbd1135423c5
# Level 2
# ...

# %%
#6
O_Soup
file1 = open("O_Soup_raw_data.txt","w")
file1.write(O_Soup)
file1.close()

# %%
#7

f = open("./O_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

O_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
O_df['SLpM'] = O_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
O_df['Str. Acc'] = O_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
O_df['SApM'] = O_df["SApM"].map(lambda x: x.replace("SApM:", ""))
O_df['Str. Def'] = O_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
O_df['TD Avg'] = O_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
O_df['TD Acc'] = O_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
O_df['TD Def'] = O_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
O_df['Sub. Avg'] = O_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
O_df.head()
# Final CSV 
O_df.to_csv("O_soup_final_.csv", index=False)

# %% [markdown]
# ## P

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=p&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


P_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(P_list["link1"])
P_Soup = ""
for link in list(P_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    P_Soup +=   "\n" + link + "\n"
    P_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/373be586f370d400
# Level 2
# CAREER STATISTICS:
# SLpM: 1.71
# Str. Acc.: 56%
# SApM: 3.42
# Str. Def: 46%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 18%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/8cb76103cd8a1562
# Level 2
# CAREER STATISTICS:
# SLpM: 1.48
# Str. Acc.: 34%
# SApM: 3.14
# Str. Def: 57%
# TD Avg.: 2.52
# TD Acc.: 43%
# TD Def.: 54%
# Sub. Avg.: 0.5
# Complete
# Level 1
# http://ufcstats.com/fighter-details/16b89be2f5c16fba
# Level 2
# CAREER STATISTICS:
# SLpM: 1.21
# Str. Acc.: 19%
# SApM: 4.14
# Str. Def: 55%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/8f4eeaf7a0df7c1a
# Level 2
# CAREER STATISTICS:
# SLpM: 2.64
# Str. Acc.: 57%
# SApM: 3.08
# Str. Def: 47%
# TD Avg.: 2.83
# TD Acc.: 27%
# TD Def.: 100%
# Sub. Avg.: 1.9
# Complete
# Level 1
# http://ufcstats.com/fighter-details/c51da79b0346b5b7
# Level 2
# ...

# %%
#6
P_Soup
file1 = open("P_Soup_raw_data.txt","w")
file1.write(P_Soup)
file1.close()

# %%
#7

f = open("./P_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

P_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
P_df['SLpM'] = P_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
P_df['Str. Acc'] = P_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
P_df['SApM'] = P_df["SApM"].map(lambda x: x.replace("SApM:", ""))
P_df['Str. Def'] = P_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
P_df['TD Avg'] = P_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
P_df['TD Acc'] = P_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
P_df['TD Def'] = P_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
P_df['Sub. Avg'] = P_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
P_df.head()
# Final CSV 
P_df.to_csv("P_soup_final_.csv", index=False)

# %% [markdown]
# ## Q

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=q&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


Q_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(Q_list["link1"])
Q_Soup = ""
for link in list(Q_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    Q_Soup +=   "\n" + link + "\n"
    Q_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/d365ee924f5cc3fc
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/f7b4cbe93f3bac06
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/aa171d55d4b5208f
# Level 2
# CAREER STATISTICS:
# SLpM: 12.25
# Str. Acc.: 78%
# SApM: 5.31
# Str. Def: 42%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 60%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/52cae54377b433b7
# Level 2
# CAREER STATISTICS:
# SLpM: 4.96
# Str. Acc.: 44%
# SApM: 2.80
# Str. Def: 66%
# TD Avg.: 0.25
# TD Acc.: 33%
# TD Def.: 60%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/2a8502954f49e682
# Level 2
# ...

# %%
#6
Q_Soup
file1 = open("Q_Soup_raw_data.txt","w")
file1.write(Q_Soup)
file1.close()

# %%
#7

f = open("./Q_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

Q_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
Q_df['SLpM'] = Q_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
Q_df['Str. Acc'] = Q_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
Q_df['SApM'] = Q_df["SApM"].map(lambda x: x.replace("SApM:", ""))
Q_df['Str. Def'] = Q_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
Q_df['TD Avg'] = Q_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
Q_df['TD Acc'] = Q_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
Q_df['TD Def'] = Q_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
Q_df['Sub. Avg'] = Q_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
Q_df.head()
# Final CSV 
Q_df.to_csv("Q_soup_final_.csv", index=False)

# %% [markdown]
# ## R

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=r&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


R_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(R_list["link1"])
R_Soup = ""
for link in list(R_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    R_Soup +=   "\n" + link + "\n"
    R_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/01b39decaf0abf6a
# Level 2
# CAREER STATISTICS:
# SLpM: 2.62
# Str. Acc.: 49%
# SApM: 2.31
# Str. Def: 51%
# TD Avg.: 1.06
# TD Acc.: 41%
# TD Def.: 71%
# Sub. Avg.: 0.4
# Complete
# Level 1
# http://ufcstats.com/fighter-details/45bc8f98d62bd096
# Level 2
# CAREER STATISTICS:
# SLpM: 1.35
# Str. Acc.: 23%
# SApM: 2.38
# Str. Def: 66%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 80%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/6cc25d19a891f435
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 7.46
# Str. Def: 37%
# TD Avg.: 4.86
# TD Acc.: 100%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/ff2c606c8bc365e3
# Level 2
# CAREER STATISTICS:
# SLpM: 0.60
# Str. Acc.: 33%
# SApM: 3.60
# Str. Def: 50%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 9.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/bc7f7f0ba3db74d2
# Level 2
# ...

# %%
#6
R_Soup
file1 = open("R_Soup_raw_data.txt","w")
file1.write(R_Soup)
file1.close()

# %%
#7

f = open("./R_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

R_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
R_df['SLpM'] = R_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
R_df['Str. Acc'] = R_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
R_df['SApM'] = R_df["SApM"].map(lambda x: x.replace("SApM:", ""))
R_df['Str. Def'] = R_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
R_df['TD Avg'] = R_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
R_df['TD Acc'] = R_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
R_df['TD Def'] = R_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
R_df['Sub. Avg'] = R_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
R_df.head()
# Final CSV 
R_df.to_csv("R_soup_final_.csv", index=False)

# %% [markdown]
# ## S

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=s&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


S_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(S_list["link1"])
S_Soup = ""
for link in list(S_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    S_Soup +=   "\n" + link + "\n"
    S_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/b1669a810fae4220
# Level 2
# CAREER STATISTICS:
# SLpM: 0.57
# Str. Acc.: 45%
# SApM: 0.96
# Str. Def: 66%
# TD Avg.: 5.73
# TD Acc.: 60%
# TD Def.: 0%
# Sub. Avg.: 1.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/7956f026e2672c47
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/2650e2f846a30f64
# Level 2
# CAREER STATISTICS:
# SLpM: 4.71
# Str. Acc.: 46%
# SApM: 3.55
# Str. Def: 60%
# TD Avg.: 0.57
# TD Acc.: 27%
# TD Def.: 60%
# Sub. Avg.: 0.3
# Complete
# Level 1
# http://ufcstats.com/fighter-details/9ba2226646046b63
# Level 2
# CAREER STATISTICS:
# SLpM: 3.97
# Str. Acc.: 46%
# SApM: 3.15
# Str. Def: 54%
# TD Avg.: 1.77
# TD Acc.: 32%
# TD Def.: 62%
# Sub. Avg.: 0.1
# Complete
# Level 1
# http://ufcstats.com/fighter-details/88d7b6d8230e1f3f
# Level 2
# ...

# %%
#6
S_Soup
file1 = open("S_Soup_raw_data.txt","w")
file1.write(S_Soup)
file1.close()

# %%
#7

f = open("./S_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

S_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
S_df['SLpM'] = S_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
S_df['Str. Acc'] = S_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
S_df['SApM'] = S_df["SApM"].map(lambda x: x.replace("SApM:", ""))
S_df['Str. Def'] = S_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
S_df['TD Avg'] = S_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
S_df['TD Acc'] = S_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
S_df['TD Def'] = S_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
S_df['Sub. Avg'] = S_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
S_df.head()
# Final CSV 
S_df.to_csv("S_soup_final_.csv", index=False)

# %% [markdown]
# ## T

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=t&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


T_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(T_list["link1"])
T_Soup = ""
for link in list(T_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    T_Soup +=   "\n" + link + "\n"
    T_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/e7bc606d269896aa
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/bb01bc3c57f39b04
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/f70144caea5c4c80
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/e13abac8089a801a
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/b4537562f88ac582
# Level 2
# CAREER STATISTICS:
# ...

# %%
#6
T_Soup
file1 = open("T_Soup_raw_data.txt","w")
file1.write(T_Soup)
file1.close()

# %%
#7

f = open("./T_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

T_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
T_df['SLpM'] = T_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
T_df['Str. Acc'] = T_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
T_df['SApM'] = T_df["SApM"].map(lambda x: x.replace("SApM:", ""))
T_df['Str. Def'] = T_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
T_df['TD Avg'] = T_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
T_df['TD Acc'] = T_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
T_df['TD Def'] = T_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
T_df['Sub. Avg'] = T_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
T_df.head()
# Final CSV 
T_df.to_csv("T_soup_final_.csv", index=False)

# %% [markdown]
# ## U

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=u&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


U_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(U_list["link1"])
U_Soup = ""
for link in list(U_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    U_Soup +=   "\n" + link + "\n"
    U_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/8f2deefe8c5dfb5d
# Level 2
# CAREER STATISTICS:
# SLpM: 1.79
# Str. Acc.: 52%
# SApM: 3.49
# Str. Def: 45%
# TD Avg.: 2.83
# TD Acc.: 50%
# TD Def.: 66%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/bcd124bcd3d5be46
# Level 2
# CAREER STATISTICS:
# SLpM: 0.13
# Str. Acc.: 21%
# SApM: 1.40
# Str. Def: 46%
# TD Avg.: 0.50
# TD Acc.: 100%
# TD Def.: 0%
# Sub. Avg.: 1.5
# Complete
# Level 1
# http://ufcstats.com/fighter-details/10ccf4ec9913cadc
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/4a1a492f299581d9
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/7a39bbac8cc0fa70
# Level 2
# ...

# %%
#6
U_Soup
file1 = open("U_Soup_raw_data.txt","w")
file1.write(U_Soup)
file1.close()

# %%
#7

f = open("./U_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

U_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
U_df['SLpM'] = U_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
U_df['Str. Acc'] = U_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
U_df['SApM'] = U_df["SApM"].map(lambda x: x.replace("SApM:", ""))
U_df['Str. Def'] = U_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
U_df['TD Avg'] = U_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
U_df['TD Acc'] = U_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
U_df['TD Def'] = U_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
U_df['Sub. Avg'] = U_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
U_df.head()
# Final CSV 
U_df.to_csv("U_soup_final_.csv", index=False)

# %% [markdown]
# ## V

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=v&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


V_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(V_list["link1"])
V_Soup = ""
for link in list(V_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    V_Soup +=   "\n" + link + "\n"
    V_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/54578e5927adea53
# Level 2
# CAREER STATISTICS:
# SLpM: 3.69
# Str. Acc.: 46%
# SApM: 4.09
# Str. Def: 57%
# TD Avg.: 3.00
# TD Acc.: 45%
# TD Def.: 31%
# Sub. Avg.: 1.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/fc1868f56d3036eb
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/8a0be41c0380188d
# Level 2
# CAREER STATISTICS:
# SLpM: 2.58
# Str. Acc.: 37%
# SApM: 2.61
# Str. Def: 77%
# TD Avg.: 1.40
# TD Acc.: 53%
# TD Def.: 75%
# Sub. Avg.: 0.5
# Complete
# Level 1
# http://ufcstats.com/fighter-details/de277a4abcfeea46
# Level 2
# CAREER STATISTICS:
# SLpM: 1.28
# Str. Acc.: 100%
# SApM: 2.55
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/663b76da637402c3
# Level 2
# ...

# %%
#6
V_Soup
file1 = open("V_Soup_raw_data.txt","w")
file1.write(V_Soup)
file1.close()

# %%
#7

f = open("./V_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

V_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
V_df['SLpM'] = V_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
V_df['Str. Acc'] = V_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
V_df['SApM'] = V_df["SApM"].map(lambda x: x.replace("SApM:", ""))
V_df['Str. Def'] = V_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
V_df['TD Avg'] = V_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
V_df['TD Acc'] = V_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
V_df['TD Def'] = V_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
V_df['Sub. Avg'] = V_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
V_df.head()
# Final CSV 
V_df.to_csv("V_soup_final_.csv", index=False)

# %% [markdown]
# ## W

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=w&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


W_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(W_list["link1"])
W_Soup = ""
for link in list(W_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    W_Soup +=   "\n" + link + "\n"
    W_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/6291decf7f3b6608
# Level 2
# CAREER STATISTICS:
# SLpM: 0.00
# Str. Acc.: 0%
# SApM: 0.00
# Str. Def: 0%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/c8097968da5e5f13
# Level 2
# CAREER STATISTICS:
# SLpM: 1.70
# Str. Acc.: 53%
# SApM: 1.75
# Str. Def: 51%
# TD Avg.: 2.60
# TD Acc.: 51%
# TD Def.: 55%
# Sub. Avg.: 1.1
# Complete
# Level 1
# http://ufcstats.com/fighter-details/6b7bc7eaf2465387
# Level 2
# CAREER STATISTICS:
# SLpM: 2.64
# Str. Acc.: 50%
# SApM: 8.57
# Str. Def: 43%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 50%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/8f2939f5fd9cca1e
# Level 2
# CAREER STATISTICS:
# SLpM: 2.02
# Str. Acc.: 51%
# SApM: 2.39
# Str. Def: 40%
# TD Avg.: 3.03
# TD Acc.: 46%
# TD Def.: 40%
# Sub. Avg.: 4.8
# Complete
# Level 1
# http://ufcstats.com/fighter-details/aeb6c57b9bd8bc3a
# Level 2
# ...

# %%
#6
W_Soup
file1 = open("W_Soup_raw_data.txt","w")
file1.write(W_Soup)
file1.close()

# %%
#7

f = open("./W_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

W_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
W_df['SLpM'] = W_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
W_df['Str. Acc'] = W_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
W_df['SApM'] = W_df["SApM"].map(lambda x: x.replace("SApM:", ""))
W_df['Str. Def'] = W_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
W_df['TD Avg'] = W_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
W_df['TD Acc'] = W_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
W_df['TD Def'] = W_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
W_df['Sub. Avg'] = W_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
W_df.head()
# Final CSV 
W_df.to_csv("W_soup_final_.csv", index=False)

# %% [markdown]
# ## X

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=x&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


X_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(X_list["link1"])
X_Soup = ""
for link in list(X_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    X_Soup +=   "\n" + link + "\n"
    X_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/e6dac752a2418a88
# Level 2
# CAREER STATISTICS:
# SLpM: 0.77
# Str. Acc.: 42%
# SApM: 1.82
# Str. Def: 21%
# TD Avg.: 2.10
# TD Acc.: 40%
# TD Def.: 25%
# Sub. Avg.: 1.1
# Complete
# Level 1
# http://ufcstats.com/fighter-details/c41d426cc7326d1b
# Level 2
# CAREER STATISTICS:
# SLpM: 6.85
# Str. Acc.: 40%
# SApM: 4.22
# Str. Def: 64%
# TD Avg.: 0.25
# TD Acc.: 50%
# TD Def.: 66%
# Sub. Avg.: 0.0
# Complete
# <class 'str'>

# %%
#6
X_Soup
file1 = open("X_Soup_raw_data.txt","w")
file1.write(X_Soup)
file1.close()

# %%
#7

f = open("./X_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

X_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
X_df['SLpM'] = X_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
X_df['Str. Acc'] = X_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
X_df['SApM'] = X_df["SApM"].map(lambda x: x.replace("SApM:", ""))
X_df['Str. Def'] = X_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
X_df['TD Avg'] = X_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
X_df['TD Acc'] = X_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
X_df['TD Def'] = X_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
X_df['Sub. Avg'] = X_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
X_df.head()
# Final CSV 
X_df.to_csv("X_soup_final_.csv", index=False)

# %% [markdown]
# ## Y

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=y&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


Y_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(Y_list["link1"])
Y_Soup = ""
for link in list(Y_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    Y_Soup +=   "\n" + link + "\n"
    Y_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/efb96bf3e9ada36f
# Level 2
# CAREER STATISTICS:
# SLpM: 4.28
# Str. Acc.: 41%
# SApM: 2.75
# Str. Def: 68%
# TD Avg.: 1.44
# TD Acc.: 100%
# TD Def.: 100%
# Sub. Avg.: 1.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/85248da6e9e2f7e7
# Level 2
# CAREER STATISTICS:
# SLpM: 3.08
# Str. Acc.: 39%
# SApM: 2.55
# Str. Def: 63%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 66%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/cc84b68f862b466f
# Level 2
# CAREER STATISTICS:
# SLpM: 3.13
# Str. Acc.: 30%
# SApM: 5.77
# Str. Def: 42%
# TD Avg.: 0.00
# TD Acc.: 0%
# TD Def.: 62%
# Sub. Avg.: 1.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/94527830000ab715
# Level 2
# CAREER STATISTICS:
# SLpM: 1.59
# Str. Acc.: 36%
# SApM: 1.61
# Str. Def: 52%
# TD Avg.: 2.92
# TD Acc.: 32%
# TD Def.: 22%
# Sub. Avg.: 2.1
# Complete
# Level 1
# http://ufcstats.com/fighter-details/d06f8869449ba7bd
# Level 2
# ...

# %%
#6
Y_Soup
file1 = open("Y_Soup_raw_data.txt","w")
file1.write(Y_Soup)
file1.close()

# %%
#7

f = open("./Y_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

Y_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
Y_df['SLpM'] = Y_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
Y_df['Str. Acc'] = Y_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
Y_df['SApM'] = Y_df["SApM"].map(lambda x: x.replace("SApM:", ""))
Y_df['Str. Def'] = Y_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
Y_df['TD Avg'] = Y_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
Y_df['TD Acc'] = Y_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
Y_df['TD Def'] = Y_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
Y_df['Sub. Avg'] = Y_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
Y_df.head()
# Final CSV 
Y_df.to_csv("Y_soup_final_.csv", index=False)

# %% [markdown]
# ## Z

# %%
#1
# Set the executable path and initialize the chrome browser 
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path)

# %%
#2

url = 'http://ufcstats.com/statistics/fighters?char=z&page=all'
browser.visit(url)
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
#3
soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())

# %%
#4

#data_b_links = soup.find_all("a", attrs={"class": "b-link"})
data_b_stats = soup.find_all("td", attrs={"class": "b-statistics__table-col"})
data_b_stats



link_list = []
for fighter_link in data_b_stats:
    if(fighter_link.a):
        link_list.append(fighter_link.a["href"])
        link_list.append(fighter_link.get_text().strip())
    else:
        link_list.append(fighter_link.get_text().strip())
final_data = []
for index in range(0, len(link_list), 14):
    final_data.append(link_list[index:index+14])


Z_list =pd.DataFrame(final_data, columns=['link1', 'First Name', "link2", "Last Name", "link3", "Nick Name", "Height", "Weight", "Reach", "Stance", "Win", "Loss", "Draw", "Champion Status"])

# %%
#5

import time
data = list(Z_list["link1"])
Z_Soup = ""
for link in list(Z_list["link1"][:]):
    print("Level 1")
    print(link)
    soup = BeautifulSoup 
    # Set the executable path and initialize the chrome browser 
    executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
    browser = Browser('chrome', **executable_path)
    browser.visit(link)
    print("Level 2")
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
#     #print(soup.prettify())
    time.sleep(1)
#     data_b_stats = soup.find_all("div", attrs={"class": "b-fight-details b-fight-details_margin-top"})
    print(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    Z_Soup +=   "\n" + link + "\n"
    Z_Soup +=(browser.execute_script("return document.getElementsByClassName('b-list__info-box-left clearfix')[0].innerText"))
    print("Complete")
    
#     print(data_b_stats)
#     print("Complete")

print(type("Finish!"))
# Out:
# Level 1
# http://ufcstats.com/fighter-details/2284092f8b63273b
# Level 2
# CAREER STATISTICS:
# SLpM: 4.56
# Str. Acc.: 32%
# SApM: 4.46
# Str. Def: 62%
# TD Avg.: 0.74
# TD Acc.: 33%
# TD Def.: 80%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/8c822811eedc11ad
# Level 2
# CAREER STATISTICS:
# SLpM: 2.99
# Str. Acc.: 64%
# SApM: 2.31
# Str. Def: 52%
# TD Avg.: 6.11
# TD Acc.: 60%
# TD Def.: 0%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/24656ef4d605c96f
# Level 2
# CAREER STATISTICS:
# SLpM: 2.81
# Str. Acc.: 39%
# SApM: 3.93
# Str. Def: 65%
# TD Avg.: 0.36
# TD Acc.: 16%
# TD Def.: 72%
# Sub. Avg.: 0.0
# Complete
# Level 1
# http://ufcstats.com/fighter-details/8adcbd525fab8d9b
# Level 2
# CAREER STATISTICS:
# SLpM: 4.27
# Str. Acc.: 41%
# SApM: 2.86
# Str. Def: 62%
# TD Avg.: 0.53
# TD Acc.: 15%
# TD Def.: 50%
# Sub. Avg.: 0.7
# Complete
# Level 1
# http://ufcstats.com/fighter-details/cc3878d1ab41a5fa
# Level 2
# ...

# %%
#6
Z_Soup
file1 = open("Z_Soup_raw_data.txt","w")
file1.write(Z_Soup)
file1.close()

# %%
#7

f = open("./Z_Soup_raw_data.txt", "r")
#print("Raw Data:")
#print(f.read())
#print("Clean Data")
#print(f.read().replace("\n", " ").replace("\t", " ").replace("\\", " ").replace("  ", " ").replace("  ", " ").split("Complete")[0])
#print(f.read().split(","))
data = f.read().split(",")


final_data = []
for index in range(0, len(data), 9):
    #print(data[index:index+9])
    final_data.append(data[index:index+9])

Z_df =pd.DataFrame(final_data, columns=['link1', "SLpM", "Str. Acc", "SApM", "Str. Def", "TD Avg", "TD Acc", "TD Def", "Sub. Avg"])

#A_soups_UP = f 
#A_soups_UP.to_csv('A_Soupy.csv', index=False,)
#R_Soup.split(" ")

# %%
#8
Z_df['SLpM'] = Z_df['SLpM'].map(lambda x: x.replace("SLpM:", ""))
Z_df['Str. Acc'] = Z_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
Z_df['SApM'] = Z_df["SApM"].map(lambda x: x.replace("SApM:", ""))
Z_df['Str. Def'] = Z_df["Str. Def"].map(lambda x: x.replace("Str. Def: ", ""))
Z_df['TD Avg'] = Z_df['TD Avg'].map(lambda x: x.replace("TD Avg.:", ""))
Z_df['TD Acc'] = Z_df['TD Acc'].map(lambda x: x.replace("TD Acc.:", ""))
Z_df['TD Def'] = Y_df['TD Def'].map(lambda x: x.replace("TD Def.:", ""))
Z_df['Sub. Avg'] = Y_df['Sub. Avg'].map(lambda x: x.replace("Sub. Avg.:", ""))





#A_df['Str. Acc'] = A_df["Str. Acc"].map(lambda x: x.replace("Str. Acc.:", ""))
Z_df.head()
# Final CSV 
Z_df.to_csv("Z_soup_final_.csv", index=False)

# %%
new_df = pd.concat((pd.read_csv(f) for f in all_files)) 
# Also, one should perhaps use os.path.join(path, "*.csv")

# %%
import glob

path = r'./A_Z_final' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame.head()
# Out:
#                                                link1  SLpM Str. Acc  SApM  \
# 0  http://ufcstats.com/fighter-details/e6dac752a2...  0.77      42%  1.82
# 1   http://ufcstats.com/fighter-details/c41d426cc...  6.85      40%  4.22
# 2  http://ufcstats.com/fighter-details/b3fb8d2293...  0.75      39%  1.10
# 3   http://ufcstats.com/fighter-details/5108b169b...  2.53      36%  5.33
# 4   http://ufcstats.com/fighter-details/4fe1d105a...  0.00       0%  0.00
#
#   Str. Def  TD Avg  TD Acc TD Def  Sub. Avg
# 0      21%    2.10     40%    25%       1.1
# 1      64%    0.25     50%    66%       0.0
# 2      46%    3.00    100%     0%       0.8
# 3      44%    0.00      0%    71%       0.0
# 4       0%    0.00      0%     0%       0.0

# %%
path = r'./A-Z fighter_list' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame1 = pd.concat(li, axis=0, ignore_index=True)

# %%
#frame1 has most fighters 

frame1.head()
# Out:
#                                                link1 First Name  \
# 0  http://ufcstats.com/fighter-details/01b39decaf...      Benji
# 1  http://ufcstats.com/fighter-details/45bc8f98d6...     Jordan
# 2  http://ufcstats.com/fighter-details/6cc25d19a8...    Gilbert
# 3  http://ufcstats.com/fighter-details/ff2c606c8b...       Josh
# 4  http://ufcstats.com/fighter-details/bc7f7f0ba3...       Amir
#
#                                                link2   Last Name  \
# 0  http://ufcstats.com/fighter-details/01b39decaf...      Radach
# 1  http://ufcstats.com/fighter-details/45bc8f98d6...       Radev
# 2  http://ufcstats.com/fighter-details/6cc25d19a8...        Rael
# 3  http://ufcstats.com/fighter-details/ff2c606c8b...    Rafferty
# 4  http://ufcstats.com/fighter-details/bc7f7f0ba3...  Rahnavardi
#
#                                                link3 Nick Name  Height  \
# 0  http://ufcstats.com/fighter-details/01b39decaf...     Razor  5' 10"
# ...

# %%
newestframe= frame1.set_index('link1').join(frame.set_index('link1'))

# %%
newestframe
# Out:
#                                                    First Name  \
# link1
# http://ufcstats.com/fighter-details/002ca196477...    Gabriel
# http://ufcstats.com/fighter-details/003d82fa384...      Aalon
# http://ufcstats.com/fighter-details/0052de90691...       Davi
# http://ufcstats.com/fighter-details/006efbb0c16...      Tyler
# http://ufcstats.com/fighter-details/008c6e1a257...     Wesley
# http://ufcstats.com/fighter-details/008cf84faae...      Bryan
# http://ufcstats.com/fighter-details/008dc37cca2...       Sean
# http://ufcstats.com/fighter-details/00a3ff40c4b...     Glaico
# http://ufcstats.com/fighter-details/00a905a4a4a...       Greg
# http://ufcstats.com/fighter-details/00debc804e2...      Dylan
# http://ufcstats.com/fighter-details/00e11b5c8b7...       Luke
# http://ufcstats.com/fighter-details/010986ee359...       John
# http://ufcstats.com/fighter-details/012fc7cd077...        Art
# http://ufcstats.com/fighter-details/013da757877...        Joe
# ...

# %%
newframe1 =newframe.dropna(subset=['First Name'])

# %%
newframe1.to_csv("mergedfighterstats.csv", index=False)

# %%
newframe.to_csv("testfighter.csv", index=False)

# %%
newestframe.to_csv("All_Fighters.csv", index=False)
