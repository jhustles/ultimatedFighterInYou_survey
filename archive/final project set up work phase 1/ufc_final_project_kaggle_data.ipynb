# %%
# Import Dependencies
import os 
import csv
import numpy as np
import pandas as pd

# %%
# Fight Stats Uniform Raw Data - 

# FIGHT STATS BY FIGHTER
fight_stats_raw = pd.read_csv('fight_stats_rds.csv', encoding='utf-8')

# %%
fight_stats_raw.head()
# Out:
#      ID   Age  Height  Weight                                      HomeTown  \
# 0  3099  29.0   162.0    52.0                                   Hebei China
# 1  3161  30.0   180.0    61.0  Anaheim, California United States of America
# 2  2263  29.0   182.0    77.0           Montclair, California Untied States
# 3  2848  26.0   165.0    52.0                Denver, Colorado United States
# 4  2375  29.0   180.0    65.0                               Brasilia Brazil
#
#                                          Location             Name   winby  \
# 0                                   Beijing China      Weili Zhang     DEC
# 1  Riverside, California United States of America      Andre Ewell     DEC
# 2                 Glendale, Arizona United States  Bryan Barberena  KO/TKO
# 3             Westminster, Colorado United States       JJ Aldrich     DEC
# 4                                 Brasilia Brazil   Renato Moicano     SUB
#
# ...

# %%
# list out all column names for analysis
column_names_raw = fight_stats_raw.columns.values

for i in enumerate(column_names_raw):
    print(i)

print(len(fight_stats_raw.columns.values))
# Out:
# (0, 'ID')
# (1, 'Age')
# (2, 'Height')
# (3, 'Weight')
# (4, 'HomeTown')
# (5, 'Location')
# (6, 'Name')
# (7, 'winby')
# (8, 'winner')
# (9, 'winner_name')
# (10, 'loser_name')
# (11, 'Date')
# (12, 'Event_ID')
# (13, 'Fight_ID')
# (14, 'Last_round')
# (15, 'estimated_minutes')
# (16, 'Max_round')
# (17, 'Round1_Grappling_Reversals_Landed')
# (18, 'Round1_Grappling_Standups_Landed')
# (19, 'Round1_Grappling_Submissions_Attempts')
# (20, 'Round1_Grappling_Takedowns_Attempts')
# (21, 'Round1_Grappling_Takedowns_Landed')
# (22, 'OPP_Round1_Grappling_Takedowns_Attempts')
# (23, 'OPP_Round1_Grappling_Takedowns_Landed')
# (24, 'Round1_Strikes_Body Significant Strikes_Attempts')
# (25, 'Round1_Strikes_Body Significant Strikes_Landed')
# (26, 'Round1_Strikes_Body Total Strikes_Attempts')
# (27, 'Round1_Strikes_Body Total Strikes_Landed')
# (28, 'Round1_Strikes_Clinch Body Strikes_Attempts')
# (29, 'Round1_Strikes_Clinch Body Strikes_Landed')
# ...

# %%
# Set up variables for significant strikes dataframe
name = fight_stats_raw['Name']

# Entire Fight Stats

estimated_minutes = fight_stats_raw['estimated_minutes']




# Round 1
# Total Overall Significant Strikes
r1_ss_att = fight_stats_raw['Round1_Strikes_Significant Strikes_Attempts']
r1_ss_landed = fight_stats_raw['Round1_Strikes_Significant Strikes_Landed']


# Significant Strikes: Head, Body, and Leg
r1_head_ss_att = fight_stats_raw['Round1_Strikes_Head Significant Strikes_Attempts']
r1_head_ss_landed = fight_stats_raw['Round1_Strikes_Head Significant Strikes_Landed']

r1_body_ss_att = fight_stats_raw['Round1_Strikes_Body Significant Strikes_Attempts']
r1_body_ss_landed = fight_stats_raw['Round1_Strikes_Body Significant Strikes_Landed']

r1_leg_ss_att = fight_stats_raw['Round1_Strikes_Legs Significant Strikes_Attempts']
r1_leg_ss_landed = fight_stats_raw['Round1_Strikes_Legs Significant Strikes_Landed']


# Clinch and Ground Strikes
r1_clinch_ss_att = fight_stats_raw['Round1_Strikes_Clinch Significant Strikes_Attempts']
r1_clinch_ss_landed = fight_stats_raw['Round1_Strikes_Clinch Significant Strikes_Landed']

r1_ground_ss_att = fight_stats_raw['Round1_Strikes_Ground Significant Strikes_Attempts']
r1_ground_ss_landed = fight_stats_raw['Round1_Strikes_Ground Significant Strikes_Landed']


#########################
# Round 2 
# Total Overall Significant Strikes
r2_ss_att = fight_stats_raw['Round2_Strikes_Significant Strikes_Attempts']
r2_ss_landed = fight_stats_raw['Round2_Strikes_Significant Strikes_Landed']


# Significant Strikes: Head, Body, and Legs
r2_head_ss_att = fight_stats_raw['Round2_Strikes_Head Significant Strikes_Attempts']
r2_head_ss_landed = fight_stats_raw['Round2_Strikes_Head Significant Strikes_Landed']

r2_body_ss_att = fight_stats_raw['Round2_Strikes_Body Significant Strikes_Attempts']
r2_body_ss_landed = fight_stats_raw['Round2_Strikes_Body Significant Strikes_Landed']

r2_leg_ss_att = fight_stats_raw['Round2_Strikes_Legs Significant Strikes_Attempts']
r2_leg_ss_landed = fight_stats_raw['Round2_Strikes_Legs Significant Strikes_Landed']


# Clinch and Ground Strikes
r2_clinch_ss_att = fight_stats_raw['Round2_Strikes_Clinch Significant Strikes_Attempts']
r2_clinch_ss_landed = fight_stats_raw['Round2_Strikes_Clinch Significant Strikes_Landed']

r2_ground_ss_att = fight_stats_raw['Round2_Strikes_Ground Significant Strikes_Attempts']
r2_ground_ss_landed = fight_stats_raw['Round2_Strikes_Ground Significant Strikes_Landed']


#########################

# Round 3 
# Total Overall Significant Strikes
r3_ss_att = fight_stats_raw['Round3_Strikes_Significant Strikes_Attempts']
r3_ss_landed = fight_stats_raw['Round3_Strikes_Significant Strikes_Landed']


# Significant Strikes: Head, Body, and Legs
r3_head_ss_att = fight_stats_raw['Round3_Strikes_Head Significant Strikes_Attempts']
r3_head_ss_landed = fight_stats_raw['Round3_Strikes_Head Significant Strikes_Landed']

r3_body_ss_att = fight_stats_raw['Round3_Strikes_Body Significant Strikes_Attempts']
r3_body_ss_landed = fight_stats_raw['Round3_Strikes_Body Significant Strikes_Landed']

r3_leg_ss_att = fight_stats_raw['Round3_Strikes_Legs Significant Strikes_Attempts']
r3_leg_ss_landed = fight_stats_raw['Round3_Strikes_Legs Significant Strikes_Landed']

# Clinch and Ground Strikes
r3_clinch_ss_att = fight_stats_raw['Round3_Strikes_Clinch Significant Strikes_Attempts']
r3_clinch_ss_landed = fight_stats_raw['Round3_Strikes_Clinch Significant Strikes_Landed']

r3_ground_ss_att = fight_stats_raw['Round3_Strikes_Ground Significant Strikes_Attempts']
r3_ground_ss_landed = fight_stats_raw['Round3_Strikes_Ground Significant Strikes_Landed']


#########################

# Round 4

# Total Overall Significant Strikes
r4_ss_att = fight_stats_raw['Round4_Strikes_Significant Strikes_Attempts']
r4_ss_landed = fight_stats_raw['Round4_Strikes_Significant Strikes_Landed']


# Significant Strikes: Head, Body, and Legs
r4_head_ss_att = fight_stats_raw['Round4_Strikes_Head Significant Strikes_Attempts']
r4_head_ss_landed = fight_stats_raw['Round4_Strikes_Head Significant Strikes_Landed']

r4_body_ss_att = fight_stats_raw['Round4_Strikes_Body Significant Strikes_Attempts']
r4_body_ss_landed = fight_stats_raw['Round4_Strikes_Body Significant Strikes_Landed']

r4_leg_ss_att = fight_stats_raw['Round4_Strikes_Legs Significant Strikes_Attempts']
r4_leg_ss_landed = fight_stats_raw['Round4_Strikes_Legs Significant Strikes_Landed']


# Clinch and Ground Strikes
r4_clinch_ss_att = fight_stats_raw['Round4_Strikes_Clinch Significant Strikes_Attempts']
r4_clinch_ss_landed = fight_stats_raw['Round4_Strikes_Clinch Significant Strikes_Landed']

r4_ground_ss_att = fight_stats_raw['Round4_Strikes_Ground Significant Strikes_Attempts']
r4_ground_ss_landed = fight_stats_raw['Round4_Strikes_Ground Significant Strikes_Landed']


#########################

# Round 5

# Total Overall Significant Strikes
r5_ss_att = fight_stats_raw['Round5_Strikes_Significant Strikes_Attempts']
r5_ss_landed = fight_stats_raw['Round5_Strikes_Significant Strikes_Landed']

# Significant Strikes: Head, Body, and Legs
r5_head_ss_att = fight_stats_raw['Round5_Strikes_Head Significant Strikes_Attempts']
r5_head_ss_landed = fight_stats_raw['Round5_Strikes_Head Significant Strikes_Landed']

r5_body_ss_att = fight_stats_raw['Round5_Strikes_Body Significant Strikes_Attempts']
r5_body_ss_landed = fight_stats_raw['Round5_Strikes_Body Significant Strikes_Landed']

r5_leg_ss_att = fight_stats_raw['Round5_Strikes_Legs Significant Strikes_Attempts']
r5_leg_ss_landed = fight_stats_raw['Round5_Strikes_Legs Significant Strikes_Landed']


# Clinch and Ground Strikes
r5_clinch_ss_att = fight_stats_raw['Round5_Strikes_Clinch Significant Strikes_Attempts']
r5_clinch_ss_landed = fight_stats_raw['Round5_Strikes_Clinch Significant Strikes_Landed']

r5_ground_ss_att = fight_stats_raw['Round5_Strikes_Ground Significant Strikes_Attempts']
r5_ground_ss_landed = fight_stats_raw['Round5_Strikes_Ground Significant Strikes_Landed']

# %%
# Build this out to get a summarized view of (fss) fighter significant strikes

fss_dict = {
    'Name': name,
    'Round1_Strikes_Significant Strikes_Attempts':r1_ss_att,
    'Round1_Strikes_Significant Strikes_landed': r1_ss_landed,
    'Round1_Strikes_Head Significant Strikes_Attempts': r1_head_ss_att,
    'Round1_Strikes_Head_Significant Strikes_Landed': r1_head_ss_landed,
    'Round1_Strikes_Body Significant Strikes_Attempts':r1_body_ss_att,
    'Round1_Strikes_Body Significant Strikes_Landed': r1_body_ss_landed,
    'Round1_Strikes_Legs Significant Strikes_Attempts': r1_leg_ss_att,
    'Round1_Strikes_Legs Significant Strikes_Landed': r1_leg_ss_landed,
    'Round1_Strikes_Clinch Significant Strikes_Attempts': r1_clinch_ss_att,
    'Round1_Strikes_Clinch Significant Strikes_Landed': r1_clinch_ss_landed,
    'Round1_Strikes_Ground Significant Strikes_Attempts': r1_ground_ss_att,
    'Round1_Strikes_Ground Significant Strikes_Landed': r1_ground_ss_landed,
    'Round2_Strikes_Significant Strikes_Attempts': r2_ss_att,
    'Round2_Strikes_Significant Strikes_landed': r2_ss_landed,
    'Round2_Strikes_Head Significant Strikes_Attempts': r2_head_ss_att,
    'Round2_Strikes_Head_Significant Strikes_Landed': r2_head_ss_landed,
    'Round2_Strikes_Body Significant Strikes_Attempts': r2_body_ss_att,
    'Round2_Strikes_Body Significant Strikes_Landed': r2_body_ss_landed,
    'Round2_Strikes_Legs Significant Strikes_Attempts': r2_leg_ss_att,
    'Round2_Strikes_Legs Significant Strikes_Landed': r2_leg_ss_landed,
    'Round2_Strikes_Clinch Significant Strikes_Attempts': r2_clinch_ss_att,
    'Round2_Strikes_Clinch Significant Strikes_Landed': r2_clinch_ss_landed,
    'Round2_Strikes_Ground Significant Strikes_Attempts': r2_ground_ss_att,
    'Round2_Strikes_Ground Significant Strikes_Landed': r2_ground_ss_landed,
    'Round3_Strikes_Significant Strikes_Attempts':r3_ss_att,
    'Round3_Strikes_Significant Strikes_landed':r3_ss_landed,
    'Round3_Strikes_Head Significant Strikes_Attempts': r3_head_ss_att,
    'Round3_Strikes_Head_Significant Strikes_Landed': r3_head_ss_landed,
    'Round3_Strikes_Body Significant Strikes_Attempts':r3_body_ss_att,
    'Round3_Strikes_Body Significant Strikes_Landed': r3_body_ss_landed,
    'Round3_Strikes_Legs Significant Strikes_Attempts': r3_leg_ss_att,
    'Round3_Strikes_Legs Significant Strikes_Landed': r3_leg_ss_landed,
    'Round3_Strikes_Clinch Significant Strikes_Attempts': r3_clinch_ss_att,
    'Round3_Strikes_Clinch Significant Strikes_Landed': r3_clinch_ss_landed,
    'Round3_Strikes_Ground Significant Strikes_Attempts': r3_ground_ss_att,
    'Round3_Strikes_Ground Significant Strikes_Landed': r3_ground_ss_landed,
    'Round4_Strikes_Significant Strikes_Attempts': r4_ss_att,
    'Round4_Strikes_Significant Strikes_landed': r4_ss_landed,
    'Round4_Strikes_Head Significant Strikes_Attempts': r4_head_ss_att,
    'Round4_Strikes_Head_Significant Strikes_Landed': r4_head_ss_landed,
    'Round4_Strikes_Body Significant Strikes_Attempts': r4_body_ss_att,
    'Round4_Strikes_Body Significant Strikes_Landed': r4_body_ss_landed,
    'Round4_Strikes_Legs Significant Strikes_Attempts': r4_leg_ss_att,
    'Round4_Strikes_Legs Significant Strikes_Landed': r4_leg_ss_landed,
    'Round4_Strikes_Clinch Significant Strikes_Attempts': r4_clinch_ss_att,
    'Round4_Strikes_Clinch Significant Strikes_Landed': r4_clinch_ss_landed,
    'Round4_Strikes_Ground Significant Strikes_Attempts': r4_ground_ss_att,
    'Round4_Strikes_Ground Significant Strikes_Landed': r4_ground_ss_landed,
    'Round5_Strikes_Significant Strikes_Attempts': r5_ss_att,
    'Round5_Strikes_Significant Strikes_landed': r5_ss_landed,
    'Round5_Strikes_Head Significant Strikes_Attempts': r5_head_ss_att,
    'Round5_Strikes_Head_Significant Strikes_Landed': r5_head_ss_landed,
    'Round5_Strikes_Body Significant Strikes_Attempts': r5_body_ss_att,
    'Round5_Strikes_Body Significant Strikes_Landed': r5_body_ss_landed,
    'Round5_Strikes_Legs Significant Strikes_Attempts': r5_leg_ss_att,
    'Round5_Strikes_Legs Significant Strikes_Landed': r5_leg_ss_landed,
    'Round5_Strikes_Clinch Significant Strikes_Attempts': r5_clinch_ss_att,
    'Round5_Strikes_Clinch Significant Strikes_Landed': r5_clinch_ss_landed,
    'Round5_Strikes_Ground Significant Strikes_Attempts': r5_ground_ss_att,
    'Round5_Strikes_Ground Significant Strikes_Landed': r5_ground_ss_landed
    }

fss_df = pd.DataFrame(fss_dict)
fss_df = fss_df.groupby(['Name']).sum()
fss_df.head()
# Out:
#                       Round1_Strikes_Significant Strikes_Attempts  \
# Name
# Aaron Phillips                                               27.0
# Abdul Razak Alhassan                                        336.0
# Abdul-Kerim Edilov                                            0.0
# Abel Trujillo                                               672.0
# Abner Lloveras                                                0.0
#
#                       Round1_Strikes_Significant Strikes_landed  \
# Name
# Aaron Phillips                                              9.0
# Abdul Razak Alhassan                                      142.0
# Abdul-Kerim Edilov                                          0.0
# Abel Trujillo                                             135.0
# Abner Lloveras                                              0.0
#
#                       Round1_Strikes_Head Significant Strikes_Attempts  \
# Name
# Aaron Phillips                                                    16.0
# ...

# %%
fss_df =
# Out:
#   File "<ipython-input-8-ee513a28db47>", line 1
#     fss_df =
#              ^
# SyntaxError: invalid syntax

# %%
#ufc_raw_data.columns.values.to_csv('column_')
